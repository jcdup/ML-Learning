# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdup/ML-Learning/blob/main/TimeSeries_warmup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Get 1000 random values from n(0,1) (std normal/gaussian) distribution:

# %%
r = np.random.randn(1000)
r.shape
# Out:
# (1000,)

# %%
r.var()
# Out:
# 1.0231883999256055

# %%
r.std()
# Out:
# 1.0115277553906297

# %%
plt.hist(r,30);

# %%
plt.plot(r);

# %% [markdown]
# Add the random values to a line:

# %%
l = np.linspace(7,20,1000)
l.shape
# Out:
# (1000,)

# %%
plt.plot(l);

# %%
y = l + r
y.shape
# Out:
# (1000,)

# %%
x=range(len(y))

# %%
x
# Out:
# range(0, 1000)

# %% [markdown]
# Plot a scatter plot of the new values:

# %%
plt.scatter(x,y);

# %%
plt.hist(x2,50);

# %% [markdown]
# Find the best fit line (should be the very close to the line we added):

# %%
a, b = np.polyfit(x,y, 1)

# %%
a
# Out:
# 0.013182551565169492

# %%
b
# Out:
# 6.914296961185116

# %%
plt.plot(x, a*x+b)

# %% [markdown]
# Try to plot the scatterplot and line on same axis

# %%
#add points to plot
#plt.scatter(x, y);

#add line of best fit to plot
#plt.plot(x, a*x+b)    ;

plt.figure(1)
plt.subplot(211)
plt.scatter(x, y);
plt.subplot(212)
plt.plot(x, a*x+b);

# %%
fig, ax = plt.subplots()
#ax.scatter(x,y)
ax.plot(x, a*x+b) #does not show--assuming it's the same color as the scatter
#ax.plot(x, y+2)  
ax.plot(x, a*x+b) #shows!
ax.scatter(x,y)
plt.show()
